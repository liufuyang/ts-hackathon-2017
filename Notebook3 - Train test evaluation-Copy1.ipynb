# %%
DATA_FOLDER = './sub_data_2/'

import matplotlib.pyplot as plt
# %matplotlib inline

import pickle
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
X = pickle.load(open(DATA_FOLDER + 'featureset.pickle', 'rb'))
Y = pickle.load(open(DATA_FOLDER + 'labels_int.pickle', 'rb'))

# %%
X_train_np, X_dev_test_np, y_train_np, y_dev_test_np = train_test_split(X, Y, test_size=0.3, random_state=42)

X_dev_np, X_test_np, y_dev_np, y_test_np = train_test_split(X_dev_test_np, y_dev_test_np, test_size=0.5, random_state=42)

# %%
# Normalization

normalizer = preprocessing.Normalizer().fit(X_train_np)

#X_train_np = normalizer.transform(X_train_np)
#X_dev_np = normalizer.transform(X_dev_np)
#X_test_np = normalizer.transform(X_test_np)

# %%
print(len(X_train_np), len(X_dev_np), len(X_test_np))
# Out:
# 47773 10237 10238

# %%
X_train_np.shape
# Out:
# (47773, 2920)

# %%
_, feature_length = X_train_np.shape
class_length =  len(np.unique(Y))

print(feature_length, class_length)
# Out:
# 2920 2699

# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F

# %%
X_train = torch.from_numpy(X_train_np).float()
y_train = torch.LongTensor(y_train_np)

X_dev = torch.from_numpy(X_dev_np).float()
y_dev = torch.LongTensor(y_dev_np)

x, y = Variable(X_train), Variable(y_train)
x_dev, y_dev = Variable(X_dev), y_dev

# %%
net = torch.nn.Sequential(
    torch.nn.Linear(feature_length, 25),
    torch.nn.ReLU(),
    torch.nn.Linear(25, class_length),
    torch.nn.LogSoftmax()
)
print(net)
# Out:
# Sequential (
#   (0): Linear (2920 -> 25)
#   (1): ReLU ()
#   (2): Linear (25 -> 2699)
#   (3): LogSoftmax ()
# )

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.02)
loss_func = torch.nn.NLLLoss()

# %%
for t in range(40):
    out = net(x)                 # input x and predict based on x
    loss = loss_func(out, y)     # must be (1. nn output, 2. target), the target label is NOT one-hotted

    optimizer.zero_grad()   # clear gradients for next train
    loss.backward()         # backpropagation, compute gradients
    optimizer.step()        # apply gradients
    
    if t % 5 == 1 or t in [0, 2]:
        # plot and show learning process
        _, prediction = torch.max(out, 1)
        pred_y = prediction.data.numpy().squeeze()
        target_y = y.data.numpy()
        
        
        out_dev = net(x_dev)
        _, prediction_dev = torch.max(out_dev, 1)
        pred_y_dev = prediction_dev.data.numpy().squeeze()
        target_y_dev = y_dev.numpy()

        acc_train = sum(pred_y == target_y)/len(target_y)
        acc_dev = sum(pred_y_dev == target_y_dev)/len(target_y_dev)
        
        print('Epoch{0:3d} -> Loss={1:.6f}, Train Acc={2:.3f}, Dev Acc={3:.3f}'.format(t+1, loss.data[0], acc_train, acc_dev))
# Out:
# Epoch  1 -> Loss=7.925055, Train Acc=0.000, Dev Acc=0.132
# Epoch  2 -> Loss=7.292356, Train Acc=0.137, Dev Acc=0.234
# Epoch  3 -> Loss=6.211340, Train Acc=0.241, Dev Acc=0.274
# Epoch  7 -> Loss=3.560422, Train Acc=0.535, Dev Acc=0.579
# Epoch 12 -> Loss=2.104285, Train Acc=0.718, Dev Acc=0.731
# Epoch 17 -> Loss=1.258105, Train Acc=0.830, Dev Acc=0.816
# Epoch 22 -> Loss=0.765825, Train Acc=0.891, Dev Acc=0.872
# Epoch 27 -> Loss=0.483275, Train Acc=0.925, Dev Acc=0.897
# Epoch 32 -> Loss=0.319755, Train Acc=0.948, Dev Acc=0.915
# Epoch 37 -> Loss=0.222236, Train Acc=0.962, Dev Acc=0.928

# %%
from sklearn import preprocessing
import numpy as np
X_train = np.array([[ 51, -1.,  2000.],
                    [ 50.,  2.,  2500.],
                   [ 30.,  1., 200.]])

scaler = preprocessing.Normalizer().fit(X_train.T)
scaler.transform(X_train.T).T
# Out:
# array([[ 0.65835231, -0.40824829,  0.62347969],
#        [ 0.64544344,  0.81649658,  0.77934961],
#        [ 0.38726606,  0.40824829,  0.06234797]])

# %% [markdown]
# ## Test Acc:

# %%
from random import randint
print()

X_test = torch.from_numpy(X_test_np).float()
y_test = torch.LongTensor(y_test_np)

x_test, y_test = Variable(X_test), y_test

out_test = net(x_test)
_, prediction_test = torch.max(out_test, 1)
#pred_y_test = [randint(0, y_test.shape[0]) for x in range(y_test.shape[0])] 
pred_y_test = prediction_test.data.numpy().squeeze()
target_y_test = y_test.numpy()

acc_test = sum(pred_y_test == target_y_test)/len(target_y_test)
print(acc_test)
# Out:
# 0.948427427232

# %% [markdown]
# ## Test with some example

# %%
y_test_np[0:5]
# Out:
# [394, 2685, 2579, 1584, 779]

# %%
doc_sender_dict = pickle.load(open(DATA_FOLDER + 'doc_sender_dict.pickle', 'rb'))
sender_id_all = pickle.load(open(DATA_FOLDER +'sender_id_all.pickle', 'rb'))

# %%
sender_id = sender_id_all[1584]
print(sender_id)

# %%
print('Documents of sender {} are:'.format(sender_id))
for doc_id, _sender_id in doc_sender_dict.items():
    if _sender_id == sender_id:
        print(doc_id)

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

lexicon = pickle.load(open(DATA_FOLDER + 'lexicon.pickle', 'rb'))

def is_valid_word(word):
    import re
    if len(word) < 1:
        return False
    if re.search('[a-zA-Z]', word) == None:
        return False
    
    return True

def parse_single_file(j):    
    words = []
    for word_info in j.get('describedWords'):
        f = word_info.get('features')
        try:
            wordHight = word_info.get('bottom')
            pageHeight = float(f.get('pageHeight'))
            relativePosition = wordHight/pageHeight
            
            if relativePosition < 1.0/3 or relativePosition > 2.0/3:
                word = word_info.get('text')
                
                if is_valid_word(word):
                    local_words_list = tokenizer.tokenize(word.lower())
                    words += local_words_list
        except:
            pass
    return words

def get_sender_name_via_id(doc_id):
    import boto3
    import botocore
    import json
    
    b_name = 'ts-dev-cs-training-data'
    prefix = 'cache_v2_individual/ubl1/hocr13/ubllight1/hocrlight1/sendertrainingmatrices20170819/data/'
    key = prefix + doc_id + '.training'
    
    obj = boto3.resource('s3').Object(b_name, key)
    doc_str = obj.get()['Body'].read().decode('utf-8')
    doc_json = json.loads(doc_str)
    
    return doc_json['sender']

def get_feature_via_words(words):
    features = np.zeros(len(lexicon))
    for word in words:
        if word in lexicon:
            index_value = lexicon.index(word)
            features[index_value] += 1
    return np.array([features])

def get_words_via_id(doc_id):
    import boto3
    import botocore
    import json
    
    b_name = 'ts-dev-cs-training-data'
    prefix = 'rbp-research/data/e2e/2017-09-11/'
    key = prefix + doc_id + '.training.json'
    
    obj = boto3.resource('s3').Object(b_name, key)
    doc_str = obj.get()['Body'].read().decode('utf-8')
    doc_json = json.loads(doc_str)
    
    print(doc_json)
    
    words = parse_single_file(doc_json)
    
    words_in_lexicon = []
    for word in words:
        if word in lexicon:
            words_in_lexicon.append(word)
    return words_in_lexicon

# %%
doc_id = '0da51d45-2069-406c-ae3c-631c62bef891'

print(get_sender_name_via_id(doc_id))

words = get_words_via_id(doc_id)
#words = ['paletten', 'paletten', 'rechnungsbetrag']
print(words)

f = get_feature_via_words(words)

f_tensor = torch.from_numpy(f).float()
f_variable = Variable(f_tensor)

out = net(f_variable)

_, prediction = torch.max(out, 1)
pred_y = prediction.data.numpy().squeeze()
print(pred_y)
# Out:
# Albromet GmbH
# {'fields': {'NUMBER': '684188', 'DATE': '2017-06-01', 'TOTAL_LINE_AMOUNT': '398.00', 'CURRENCY_CODE': 'EUR', 'BUYERS_ORDER_ID': '30379532', 'TOTAL_TAX_AMOUNT': '75.62', 'TOTAL': '473.62', 'SUB_TOTAL_TAX_CATEGORY_PERCENT': '19'}, 'describedWords': [{'pageNumber': 0, 'top': 1049, 'bottom': 1063, 'left': 762, 'right': 799, 'text': '75,62', 'features': {'TextOfTwoWordsLeft': 'MwSt.', 'rightMargin': 0.8957399129867554, 'leftAlignment': 1.0, 'TextPatterns': '00?00', 'LineMathFeatures.isProduct': 'NO', 'parsesAsAmount': 'YES', 'pageHeight': 1262.0, 'lineSize': 4.0, 'isKnownCountry': 'NO', 'leftMarginRelative': -0.16423766314983368, 'parsesAsDate': 'NO', 'rightMarginRelative': 'N/A', 'LineMathFeatures.isFactor': 'NO', 'pageWidth': 892.0, 'length': 5.0, 'RawTextLastWord': '', 'positionOnLine': 0.75, 'topMargin': 0.831220269203186, 'bottomMargin': 0.8423137664794922, 'horizontalPosition': 'N/A', 'lineWhiteSpace': 0.9585201740264893, 'RawText': '75,62', 'topMarginRelative': -0.014263074845075607, 'bottomMarginRelative': 0.028526149690151215, 'isKnownCity': 'NO', 'isKnownZip': 'NO', 'parsesAsNumber': 'YES', 'leftMargin': 0.8542600870132446, 'hasDigits': 'YES', 'verticalPosition': 0.3333333432674408}}, {'pageNumber': 0, 'top': 595, 'bottom': 609, 'left': 361, 'right': 368, 'text': 'ø', 'features': {'TextOfTwoWordsLeft': 'Nr.', 'rightMargin': 0.4125560522079468, 'leftAlignment': 4.0, 'TextPatterns': 'x', 'LineMathFeatures.isProduct': 'NO', 'parsesAsAmount': 'NO', 'pageHeight': 1262.0, 'lineSize': 5.0, 'isKnownCountry': 'NO', 'leftMarginRelative': -0.07343049347400665, 'parsesAsDate': 'NO', 'rightMarginRelative': 0.01905829645693302, 'LineMathFeatures.isFactor': 'NO', 'pageWidth': 892.0, 'length': 1.0, 'RawTextLastWord': '', 'positionOnLine': 0.4000000059604645, 'topMargin': 0.4714738428592682, 'bottomMargin': 0.48256734013557434, 'horizontalPosition': 0.7939394116401672, 'lineWhiteSpace': 0.9921524524688721, 'RawText': 'ø', 'topMarginRelative': -0.013470681384205818, 'bottomMarginRelative': 0.030110934749245644, 'isKnownCity': 'YES', 'isKnownZip': 'NO', 'parsesAsNumber': 'NO', 'leftMargin': 0.40470853447914124, 'hasDigits': 'NO', 'verticalPosition': 0.30909091234207153}}, {'pageNumber': 0, 'top': 527, 'bottom': 541, 'left': 756, 'right': 799, 'text': 'EURO', 'features': {'TextOfTwoWordsLeft': 'Bezeichnung', 'rightMargin': 0.8957399129867554, 'leftAlignment': 6.0, 'TextPatterns': 'XXXX', 'LineMathFeatures.isProduct': 'NO', 'parsesAsAmount': 'NO', 'pageHeight': 1262.0, 'lineSize': 6.0, 'isKnownCountry': 'NO', 'leftMarginRelative': -0.12107623368501663, 'parsesAsDate': 'NO', 'rightMarginRelative': 'N/A', 'LineMathFeatures.isFactor': 'NO', 'pageWidth': 892.0, 'length': 4.0, 'RawTextLastWord': '', 'positionOnLine': 0.8333333134651184, 'topMargin': 0.4175911247730255, 'bottomMargin': 0.42868462204933167, 'horizontalPosition': 'N/A', 'lineWhiteSpace': 0.9517937302589417, 'RawText': 'EURO', 'topMarginRelative': -0.014263074845075607, 'bottomMarginRelative': 0.028526149690151215, 'isKnownCity': 'YES', 'isKnownZip': 'NO', 'parsesAsNumber': 'NO', 'leftMargin': 0.847533643245697, 'hasDigits': 'NO', 'verticalPosition': 0.3333333432674408}}, {'pageNumber': 0, 'top': 293, 'bottom': 307, 'left': 465, 'right': 543, 'text': 'Kd.UStIDNr', 'features': {'TextOfTwoWordsLeft': 'DE-66539', 'rightMargin': 0.6087443828582764, 'leftAlignment': 11.0, 'TextPatterns': 'Xx?XXxXXXx', 'LineMathFeatures.isProduct': 'NO', 'parsesAsAmount': 'NO', 'pageHeight': 1262.0, 'lineSize': 4.0, 'isKnownCountry': 'NO', 'leftMarginRelative': -0.3413677215576172, 'parsesAsDate': 'NO', 'rightMarginRelative': 0.1182735413312912, 'LineMathFeatures.isFactor': 'NO', 'pageWidth': 892.0, 'length': 10.0, 'RawTextLastWord': '', 'positionOnLine': 0.5, 'topMargin': 0.2321711629629135, 'bottomMargin': 0.24326466023921967, 'horizontalPosition': 0.742682933807373, 'lineWhiteSpace': 0.9125560522079468, 'RawText': 'Kd.UStIDNr', 'topMarginRelative': -0.014263074845075607, 'bottomMarginRelative': 0.0142630 ...
# ['kd', 'co', 'werk', 'geschäftsführer', 'münchen', 'hrb', 'ab', 'zahlbar', 'kunden', 'nr', 'iban', 'code', 'warenwert', 'straße', 'eberspächer', 'bis', 'euro', 'datum', 'bis', 'e', 'mail', 'info', 'peter', 'kg', 'nr', 'gesamt', 'sparkasse', 'technology', 'neunkirchen', 'gesamtsumme', 'skonto', 'gmbh', 'postfach', 'bank', 'mit', 'telefax', 'tel', 'rechnung', 'auftrag', 'homburger', 'ls', 'nr', 'mwst', 'deutschland', 'netto', 'swift', 'bic', 'summe', 'gmbh', 'ust', 'idnr', 'internet', 'd', 'zahlbar', 'liefer', 'datum', 'telefon', 'gmbh', 'o', 'www', 'exhaust']
# 1584
